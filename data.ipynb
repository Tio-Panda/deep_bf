# %%
# %load_ext autoreload
# %autoreload 2

from deep_bf.data_handler import DataLoader
import torch
import numpy as np

dl = DataLoader("/home/panda/rf_data/")

nz = 2048
nx = 256

device = "cuda"
dtype = torch.float32
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import h5py
path = "/home/panda/rf_data/dl_data/carotid_cross_expe_dataset_rf.hdf5"

with h5py.File(path, "r") as f:
    print(f.attrs["c0"])
# Out:
# 1540.0

# %%
from deep_bf.models import get_dataset

data_path = "/home/panda/rf_data/dl_data"
factor = 0.9
seed = 42
batch_size = 1
transorm = True
pin_memory = False
num_workers = 8
dtype_np = np.float32

train, val = get_dataset(
    data_path=data_path, 
    factor=factor,
    seed=seed,
    transform=transorm,
    pin_memory=pin_memory,
    num_workers=num_workers,
    dtype=dtype_np)

# %%
input, target = next(iter(train))
print(input["rf"].shape, target.shape)
# Out:
# torch.Size([1, 128, 2800, 1]) torch.Size([1, 2048, 256])

# %%
# Display image and label.
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].squeeze()
label = train_labels[0]
plt.imshow(img, cmap="gray")
plt.show()
print(f"Label: {label}")
